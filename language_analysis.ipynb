# %% [markdown]
# # TF-IDF with PySpark: Investigating the consumer financial complaint database

# %% [markdown]
# ## John Snow Spark NLP package
# See [this Quick Start Guide](https://nlp.johnsnowlabs.com/docs/en/quickstart)
#
# and/or [this quick start guide](https://github.com/JohnSnowLabs/spark-nlp)
#
# I used aspects of each, personally. Some highlights:
#
# If you haven't already installed PySpark (note: PySpark version 2.4.4 is the only supported version):
# $ conda install pyspark==2.4.4
# $ conda install -c johnsnowlabs spark-nlp
#
# If you already have PySpark, make sure to install spark-nlp in the same channel as PySpark. In my case PySpark is in my conda-forge channel, so I used:
# $ conda install -c johnsnowlabs spark-nlp --channel conda-forge
#
# I already had PySpark installed and set up for use with jupyter notebooks, but if you don't, you may need to set some additional environment variables in the terminal (as mentioned in the second quick start guide, but not the first, so I'm not positive):
#
# export SPARK_HOME=/path/to/your/spark/folder
#
# export PYSPARK_PYTHON=python3
#
# export PYSPARK_DRIVER_PYTHON=jupyter
#
# export PYSPARK_DRIVER_PYTHON_OPTS=notebook

# %%
# if you don't need to access the SparkSession:
# import sparknlp
# sparknlp.start()

# %% [markdown]
# since i need the spark session to load the data from my parquet file, I'll start a "custom" SparkSession

# %%
from pyspark.sql import SparkSession

# start spark session configured for spark nlp
spark = SparkSession.builder \
    .master('local[*]') \
    .appName('Spark NLP') \
    .config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.11:2.3.5") \
    .getOrCreate()

# set to pandas-like output
spark.conf.set("spark.sql.repl.eagerEval.enabled", True)

# %%
# get the list of stopwords from nltk
from nltk.corpus import stopwords

eng_stopwords = stopwords.words('english')
eng_stopwords.append('xxxx')

# %% [markdown]
# ### Set up pipeline

# %%
from sparknlp.base import Finisher, DocumentAssembler
from sparknlp.annotator import (Tokenizer, Normalizer, 
                                LemmatizerModel, StopWordsCleaner)
from pyspark.ml import Pipeline

# %% [markdown]
# Start with the documentAssembler, then see the annotator [docs](https://nlp.johnsnowlabs.com/docs/en/annotators) to for the available annotators. Convert back to human-readable form at the end with a Finnisher.

# %%
documentAssembler = DocumentAssembler() \
    .setInputCol('consumer_complaint_narrative') \
    .setOutputCol('document')

tokenizer = Tokenizer() \
    .setInputCols(['document']) \
    .setOutputCol('token')

# note normalizer defaults to changing all words to lowercase.
# Use .setLowercase(False) to maintain input case.
normalizer = Normalizer() \
    .setInputCols(['token']) \
    .setOutputCol('normalized') \
    .setLowercase(True)

# note that lemmatizer needs a dictionary. So I used the pre-trained
# model (note that it defaults to english)
lemmatizer = LemmatizerModel.pretrained() \
    .setInputCols(['normalized']) \
    .setOutputCol('lemma') \

stopwords_cleaner = StopWordsCleaner() \
    .setInputCols(['lemma']) \
    .setOutputCol('clean_lemma') \
    .setCaseSensitive(False) \
    .setStopWords(eng_stopwords)

# finisher converts tokens to human-readable output
finisher = Finisher() \
    .setInputCols(['clean_lemma']) \
    .setCleanAnnotations(False)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]

# %% [markdown]
# #### Defining the pipeline

# %%
pipeline = Pipeline() \
    .setStages([
        documentAssembler,
        tokenizer,
        normalizer,
        lemmatizer,
        stopwords_cleaner,
        finisher
    ])

# %% [markdown]
# ## Import data and apply pipeline

# %% [markdown]
# Note: info on how to get this parquet file here:
#
# data set: https://catalog.data.gov/dataset/consumer-complaint-database
#
# my transformation from csv to parquet: https://github.com/allisonhonold/spark-blog/blob/master/pyspark_blog.ipynb

# %%
# import data
df = spark.read.load('../data/consumer_complaints.parquet',
                     inferSchema="true", header="true")

# %%
# select equifax data as test
data = df.filter((df['company'] == 'EQUIFAX, INC.') 
                & (df['consumer_complaint_narrative'].isNull() == False))

# %%
# transform text with the pipeline
equifax = pipeline.fit(data).transform(data)

# %%
equifax.columns
# Out:
# ['date_received',
#  'product',
#  'sub-product',
#  'issue',
#  'sub-issue',
#  'consumer_complaint_narrative',
#  'company_public_response',
#  'company',
#  'state',
#  'zip_code',
#  'tags',
#  'consumer_consent_provided?',
#  'submitted_via',
#  'date_sent_to_company',
#  'company_response_to_consumer',
#  'timely_response?',
#  'consumer_disputed?',
#  'complaint_id',
#  'document',
#  'token',
#  'normalized',
#  'lemma',
#  'clean_lemma',
#  'finished_clean_lemma']

# %%
equifax.select('finished_clean_lemma')
# Out:
# +--------------------+
# |finished_clean_lemma|
# +--------------------+
# |[address, never, ...|
# |[pay, satisfied, ...|
# |[send, equifax, m...|
# |[since, fill, ide...|
# |[massive, equifax...|
# |[accident, multip...|
# |[keep, breach, se...|
# |[numerous, accoun...|
# |[ks, dispute, col...|
# |[number, inquries...|
# |[believe, equifax...|
# |[overview, proble...|
# |[equifax, experie...|
# |[try, log, disput...|
# |[victim, identity...|
# |[try, get, free, ...|
# |[submit, complain...|
# |[equifax, update,...|
# |[really, hope, he...|
# |[please, see, att...|
# +--------------------+
# only showing top 20 rows

# %%
# expand the "finished_clean_lemma" column so that the words are not in a list
from pyspark.sql.functions import explode, col

equifax_words = equifax.withColumn("exploded_text", explode(col("finished_clean_lemma")))

# %%
equifax_words.columns
# Out:
# ['date_received',
#  'product',
#  'sub-product',
#  'issue',
#  'sub-issue',
#  'consumer_complaint_narrative',
#  'company_public_response',
#  'company',
#  'state',
#  'zip_code',
#  'tags',
#  'consumer_consent_provided?',
#  'submitted_via',
#  'date_sent_to_company',
#  'company_response_to_consumer',
#  'timely_response?',
#  'consumer_disputed?',
#  'complaint_id',
#  'document',
#  'token',
#  'normalized',
#  'lemma',
#  'clean_lemma',
#  'finished_clean_lemma',
#  'exploded_text']

# %%
counts = equifax_words.groupby('exploded_text').count()

# %%
counts_pd = counts.toPandas()

# %%
counts_pd
# Out:
#        exploded_text  count
# 0             online   4300
# 1              still  10241
# 2               hope    811
# 3            tarnish     27
# 4        transaction   2362
# ...              ...    ...
# 28068  ftcgovequifax      1
# 28069            msr      1
# 28070       relegate      2
# 28071    celebration      1
# 28072       xxxxanks      1
#
# [28073 rows x 2 columns]

# %%
counts_pd.shape
# Out:
# (28073, 2)

# %%
{counts_pd.loc[i, 'exploded_text']: counts_pd.loc[i, 'count'] for i in range(counts_pd.shape[0])}
# Out:
# {'online': 4300,
#  'still': 10241,
#  'hope': 811,
#  'tarnish': 27,
#  'transaction': 2362,
#  'enablement': 77,
#  'randomly': 61,
#  'requirement': 647,
#  'input': 119,
#  'hud': 27,
#  'degrade': 76,
#  'recognize': 726,
#  'elevate': 12,
#  'backdate': 31,
#  'priority': 61,
#  'everyday': 59,
#  'medicare': 23,
#  'smartconnect': 1,
#  'interaction': 27,
#  'travel': 92,
#  'implore': 16,
#  'dbt': 1,
#  'uptodate': 17,
#  'responed': 7,
#  'trail': 148,
#  'electrical': 5,
#  'deleterious': 7,
#  'dnt': 1,
#  'thwart': 7,
#  'athree': 1,
#  'alady': 1,
#  'premeditated': 2,
#  'likelihood': 16,
#  'treid': 1,
#  'barrier': 44,
#  'ransom': 5,
#  'countermeasure': 1,
#  'art': 13,
#  'stateowned': 3,
#  'confidentiality': 13,
#  'xxxxb': 1,
#  'xxxxxxxxwith': 7,
#  'persist': 43,
#  'indigenous': 2,
#  'resolvednothing': 1,
#  'jewelry': 17,
#  'socialsecurity': 4,
#  'imitation': 2,
#  'historys': 2,
#  'indicator': 23,
#  'isp': 2,
#  'lemonxxxx': 1,
#  'understad': 1,
#  'beem': 1,
#  'unmodified': 2,
#  'currentcreditcardopenequifaxxxxx': 1,
#  'xxxxxxxxwei': 1,
#  'yearsif': 4,
#  'removingchanging': 1,
#  'precautionary': 5,
#  'incompliance': 5,
#  'solicitationoffering': 1,
#  'moxxxx': 4,
#  'inner': 2,
#  'creditorsxxxx': 2,
#  'xxxxequifaxunauthorizedcreditinquiry': 1,
#  'commentsdisputes': 1,
#  'reseach': 1,
#  'yearsrules': 1,
#  'tride': 1,
#  'outfit': 11,
#  'cautious': 5,
#  'bifurcate': 2,
#  'unavoidably': 1,
#  'updatedverified': 2,
#  'beforethese': 1,
#  'blossom': 1,
#  'destitute': 2,
#  'intentionto': 1,
#  'immediatelyclosing': 1,
#  'aggreing': 1,
#  'plete': 1,
#  'amso': 1,
#  'rejuvenate': 2,
#  'fiscally': 3,
#  'ecause': 2,
#  'soundness': 1,
#  'embrace': 1,
#  'andxxxxxxxxmonthly': 1,
#  'myconsumer': 1,
#  'badily': 3,
#  'pushback': 2,
#  'resalee': 1,
#  'spoil': 4,
#  'bureausit': 1,
#  'believei': 1,
#  'woroking': 1,
#  'timetable': 1,
#  'reco': 1,
#  'recogjnwedsized': 1,
#  'oir': 1,
#  'guts': 1,
#  'insuranceassurance': 1,
#  'convergent': 1,
#  'disputeinvestigate': 1,
#  'suppervisors': 1,
#  'consistenly': 2,
#  'ileagally': 1,
#  'accessview': 2,
#  'ligament': 1,
#  'forfor': 1,
#  'cantreport': 1,
#  'xxxxopenedxxxxxxxxbalance': 1,
#  'oscar': 1,
#  'xxxxduplicateon': 1,
#  'theough': 1,
#  'operati': 1,
#  'paymentwithout': 1,
#  'newlywed': 2,
#  'didi': 2,
#  'saidyou': 1,
#  'crest': 1,
#  'brxxxx': 2,
#  'accumulation': 2,
#  'auds': 2,
#  'ormation': 2,
#  'releasedsatisfied': 1,
#  'verifacition': 3,
#  'cancelledwithdrawn': 1,
#  'counbtries': 1,
#  'recordemployment': 1,
#  'equafaix': 1,
#  'alws': 2,
#  'odviously': 1,
#  'highwaysend': 1,
#  'sufficent': 4,
#  'legaly': 2,
#  'assupmtion': 1,
#  'unequivocal': 2,
#  'wtih': 4,
#  'argumenting': 1,
#  'recommit': 1,
#  'periodhistorical': 1,
#  'informationincorrectunsupported': 1,
#  'happenhow': 1,
#  'lended': 1,
#  'timesthe': 1,
#  'freezelift': 2,
#  'unlegible': 1,
#  'tothis': 1,
#  'faultsand': 1,
#  'sourcebook': 1,
#  'optionway': 1,
#  'fixedterm': 1,
#  'xxxxkeeps': 1,
#  'accountmistaken': 6,
#  'hardinquiries': 1,
#  'reportnothing': 1,
#  'recommendyou': 1,
#  'selfemp': 1,
#  'autopays': 1,
#  'respectably': 1,
#  'sourceequifax': 1,
#  'monthstheir': 1,
#  'include': 5717,
#  'operation': 156,
#  'absurd': 215,
#  'positive': 413,
#  'conversation': 464,
#  'mafia': 3,
#  'enhancement': 14,
#  'staff': 154,
#  'auction': 82,
#  'partially': 40,
#  'jurisdiction': 92,
#  'often': 127,
#  'collectable': 7,
#  'mortgagerelated': 2,
#  'wrongdoing': 23,
#  'television': 20,
#  'launch': 35,
#  'youplease': 1,
#  'slightly': 28,
#  'allegationsfromtheconsumer': 1,
#  'column': 32,
#  'indictment': 11,
#  'burreaus': 1,
#  'robosigning': 1,
#  'speedy': 12,
#  'inofrmation': 5,
#  'retailer': 17,
#  'bone': 4,
#  'witjh': 1,
#  'allowes': 1,
#  'forceplaced': 3,
#  'nitemare': 1,
#  'drain': 28,
#  'hurry': 10,
#  'bnackruptcy': 1,
#  'frauduantly': 1,
#  'pus': 1,
#  'liaten': 1,
#  'col': 2,
#  'falselyi': 1,
#  'unauthorizedunknown': 4,
#  'accountit': 4,
#  'detain': 2,
#  'responsecfpb': 2,
#  'xxxxxxxxinquiry': 13,
#  'oddly': 8,
#  'conspicuous': 7,
#  'xxxxinformation': 1,
#  'notterized': 1,
#  'faud': 2,
#  'taylored': 1,
#  'undeterred': 1,
#  'postive': 3,
#  'authorit': 2,
#  'colo': 1,
#  'satisfiedshortly': 3,
#  'householdhowever': 1,
#  'collectionsxxxx': 5,
#  'biase': 1,
#  'clsims': 1,
#  'productive': 5,
#  'import': 5,
#  'xxxxxxxxremove': 1,
#  'xxxxxxxxtype': 3,
#  'wrestle': 1,
#  'manipulative': 4,
#  'photograph': 5,
#  'contractagreement': 10,
#  'firedsent': 1,
#  'gadget': 2,
#  'creditbankrupcy': 1,
#  'pmbulls': 1,
#  'unbothered': 1,
#  'outgoing': 7,
#  'instantiate': 1,
#  'subscriptionsomething': 1,
#  'confirmable': 1,
#  'wva': 3,
#  'distributor': 2,
#  'openeded': 1,
#  'equifaxsays': 1,
#  'continueslly': 1,
#  'expertise': 5,
#  'goe': 2,
#  'businesswe': 1,
#  'repoorting': 1,
#  'predominant': 1,
#  'seemlngly': 1,
#  'motorist': 2,
#  'courtconsidering': 1,
#  'asapmy': 1,
#  'accountinformation': 1,
#  'fonacne': 1,
#  'carand': 1,
#  'nondisclosure': 1,
#  'secutive': 1,
#  'beeb': 1,
#  'whiped': 1,
#  'paymentmadexxxxhigh': 1,
#  'hackit': 1,
#  'fashioni': 1,
#  'yourselfplease': 1,
#  'problemat': 1,
#  'numeroud': 1,
#  'anyplace': 1,
#  'tradings': 1,
#  'maintaing': 1,
#  'billingi': 1,
#  'regularity': 1,
#  'affividat': 1,
#  'ingnored': 1,
#  'logistically': 1,
#  'debtc': 1,
#  'carryover': 1,
#  'assignorlender': 1,
#  'llisted': 1,
#  'equifaxcomxxxxxxxx': 1,
#  'cognizant': 1,
#  'hipp': 2,
#  'freee': 1,
#  'aayou': 2,
#  'xxxxfine': 1,
#  'vocal': 1,
#  'infomtion': 1,
#  'prover': 1,
#  'sceptical': 1,
#  'ard': 1,
#  'falsey': 1,
#  'cabal': 1,
#  'facetoface': 1,
#  'pymtss': 1,
#  'continuos': 1,
#  'balanceally': 1,
#  'explain': 2338,
#  'futile': 14,
#  'fax': 2478,
#  'frustrate': 595,
#  'dmv': 35,
#  'ct': 152,
#  'hometown': 3,
#  'equal': 110,
#  'inadmissible': 5,
#  'cable': 148,
#  'achieve': 46,
#  'cosigning': 8,
#  'xxxxxxxxwhich': 8,
#  'disaster': 167,
#  'watch': 98,
#  'premiere': 7,
#  'haunt': 26,
#  'growth': 16,
#  'guideprint': 2,
#  'creditorxxxx': 8,
#  'sumitted': 4,
#  'demeaning': 4,
#  'afterwards': 37,
#  'xxxxt': 43,
#  'evaluation': 21,
#  'ove': 7,
#  'disprove': 6,
#  'pbecause': 3,
#  'relevent': 1,
#  'contactable': 1,
#  'plane': 3,
#  'bloc': 4,
#  'onxxxxiplacedasecurityfreezeonmyfilewithxxxxxxxxxxxx': 1,
#  'wthe': 1,
#  'gall': 11,
#  'recieving': 20,
#  'rexxxx': 2,
#  'amp': 24,
#  'isrequire': 1,
#  'doctrine': 13,
#  'lende': 3,
#  'coin': 13,
#  'transferredsold': 24,
#  'reportworst': 21,
#  'intercept': 30,
#  'responsibilityindividualremarksmedicaloriginal': 2,
#  'agonizingly': 1,
#  'creditorfurnisher': 5,
#  'definately': 2,
#  'wwwfreezeequifaxcom': 4,
#  'shortestlived': 1,
#  'hockey': 1,
#  'jpg': 5,
#  'requestdemands': 7,
#  'ey': 3,
#  'furnisherbankruptcy': 1,
#  'ld': 1,
#  'folder': 12,
#  'neglagence': 5,
#  'disarray': 1,
#  'postpone': 5,
#  'refurnish': 4,
#  'keyboard': 3,
#  'xxxxhas': 4,
#  'opendxxxxxxxx': 1,
#  'contractsame': 1,
#  'willbe': 2,
#  'der': 4,
#  'lords': 1,
#  'chalk': 1,
#  'tellling': 1,
#  'correspondencecommunication': 3,
#  'recvied': 2,
#  'cba': 3,
#  'youyour': 1,
#  'xxxxclaim': 2,
#  'doneiam': 1,
#  'hub': 2,
#  'oblivious': 5,
#  'doublebill': 1,
#  'refrigerator': 1,
#  'maintence': 1,
#  'oftodaythey': 2,
#  'affvaidts': 1,
#  'prequalificationpreapproval': 1,
#  'refinancimng': 1,
#  'docusign': 2,
#  'repossessioncharge': 1,
#  'stronghold': 2,
#  'bankruptcyactually': 1,
#  'nppi': 2,
#  'wrost': 2,
#  'feedbackstudentaidedgov': 1,
#  'detrimentally': 2,
#  'deletedxxxxxxxx': 1,
#  'removedsome': 1,
#  'fruitlessly': 2,
#  'anythingnow': 1,
#  'asmy': 1,
#  'modernization': 1,
#  'unconscienable': 1,
#  'presidentceo': 2,
#  'havesubmitted': 1,
#  'theinstructions': 1,
#  'alia': 1,
#  'updae': 1,
#  'wwwtrusteidcom': 1,
#  'xxxxverified': 1,
#  'credet': 1,
#  'adreana': 1,
#  'aboveequifax': 1,
#  'acctbeing': 1,
#  'disputingthe': 1,
#  'tle': 1,
#  'leanlevy': 2,
#  'educationxxxxt': 1,
#  'onxxxxxxxxafter': 1,
#  'expungedxxxx': 1,
#  'verifiedinvalidated': 1,
#  'couty': 1,
#  'xxxxwill': 1,
#  'xxxxxxxxscore': 1,
#  'ommission': 1,
#  'retriever': 1,
#  'ked': 1,
#  'homesmortgages': 1,
#  'apthome': 1,
#  'crerdit': 1,
#  'itfix': 1,
#  'occasionsonly': 1,
#  'hasd': 1,
#  'dispersal': 1,
#  'incited': 2,
#  'fletcher': 1,
#  'fcrawith': 1,
#  'nondelivery': 1,
#  'closureplease': 1,
#  'usdept': 1,
#  'staffin': 1,
#  'clarifiy': 1,
#  'numbersi': 1,
#  'decay': 1,
#  'drugstore': 1,
#  'letterremove': 1,
#  'goodfaith': 1,
#  'map': 2,
#  'indiscretion': 2,
#  'cook': 1,
#  'tricredit': 1,
#  'settlement': 757,
#  'accusation': 226,
#  'prevent': 1293,
#  'incur': 203,
#  'extension': 175,
#  'character': 244,
#  'shut': 153,
#  'obsolete': 59,
#  'slow': 68,
#  'audacity': 10,
#  'tri': 3,
#  'satisfactor': 1,
#  'divulge': 69,
#  'naction': 1,
#  'disclaimer': 27,
#  'dive': 17,
#  'perspective': 12,
#  'fastfoward': 1,
#  'accout': 14,
#  'typically': 77,
#  'scurrilous': 1,
#  'xxxxbased': 3,
#  'pmt': 7,
#  'didcompliance': 84,
#  'verbatim': 17,
#  'cppb': 1,
#  'eligibility': 31,
#  'stomach': 2,
#  'uspa': 1,
#  'farm': 11,
#  'en': 16,
#  'maintance': 1,
#  'foregoing': 14,
#  'ira': 4,
#  'bench': 2,
#  'offload': 3,
#  'opposition': 6,
#  'servant': 4,
#  'superviso': 1,
#  'estoppel': 15,
#  'disidentifications': 2,
#  'stringent': 5,
#  'renewreopen': 1,
#  'intact': 9,
#  'sanitized': 1,
#  'ascend': 4,
#  'repossed': 5,
#  'submenus': 1,
#  'blockremove': 4,
#  'xxxxxxxxmultiple': 1,
#  'xxxxive': 1,
#  'incorrectness': 4,
#  'beuaraus': 1,
#  'badit': 1,
#  'creditbureau': 2,
#  'equifacx': 1,
#  'buxxxx': 1,
#  'wy': 4,
#  'gasoline': 3,
#  'doi': 6,
#  'undetected': 2,
#  'accountjudgment': 2,
#  'supplycfpb': 1,
#  'unaccessible': 1,
#  'verfiied': 1,
#  'bureocracy': 1,
#  'abundantly': 3,
#  'ffel': 4,
#  'inquiryhow': 1,
#  'staunchly': 1,
#  'enquiriesthere': 1,
#  'delte': 1,
#  'chpter': 1,
#  'nev': 1,
#  'suicide': 2,
#  'asyou': 1,
#  'stove': 1,
#  'invesigate': 1,
#  'paidnever': 3,
#  'teck': 1,
#  'agre': 1,
#  'anti': 2,
#  'knowlege': 3,
#  'aacount': 2,
#  'xxxxxxxxcompany': 14,
#  'annoucement': 1,
#  'midway': 2,
#  'collectionscharged': 2,
#  'wasntplease': 1,
#  'forbarance': 1,
#  'predjuice': 1,
#  'thembut': 1,
#  'floodgate': 1,
#  'rhode': 2,
#  'overthrow': 2,
#  'sameit': 1,
#  'calldid': 2,
#  'eqauifax': 2,
#  'flied': 1,
#  'presentment': 3,
#  'walgreens': 1,
#  'presente': 1,
#  'repiled': 1,
#  'babe': 1,
#  'immediatelyive': 1,
#  'kequifax': 1,
#  'hackedthis': 1,
#  'nondisplay': 2,
#  'dpa': 1,
#  'globally': 1,
#  'companybor': 1,
#  'frcathey': 1,
#  'frozenblocked': 1,
#  'collare': 1,
#  'succinctly': 1,
#  'generalconsumer': 4,
#  'committedalleged': 1,
#  'drasticly': 1,
#  'jar': 1,
#  'issueper': 1,
#  'billiondollar': 1,
#  'valley': 1,
#  'acctnxxxx': 1,
#  'monthwould': 1,
#  'writingcalling': 1,
#  'familier': 1,
#  'det': 1,
#  'twicedisputed': 1,
#  'dminn': 1,
#  'ss': 775,
#  'leave': 1248,
#  'grow': 81,
#  'remedy': 464,
#  'robotic': 16,
#  'soooo': 4,
#  'thick': 11,
#  'ready': 190,
#  'csr': 55,
#  'promblem': 1,
#  'port': 24,
#  'reliant': 2,
#  'wall': 40,
#  'uncitral': 7,
#  'dozen': 58,
#  'uest': 3,
#  'periodic': 20,
#  'debate': 15,
#  'issuer': 64,
#  'imbalance': 3,
#  'forge': 58,
#  'reportings': 61,
#  'extraordinarily': 4,
#  'cpi': 11,
#  'evil': 16,
#  'boost': 15,
#  'oversee': 28,
#  'favorable': 45,
#  'bofa': 2,
#  'revise': 85,
#  'triplicate': 4,
#  'scary': 18,
#  'pi': 105,
#  'traffic': 16,
#  'conct': 1,
#  'waa': 1,
#  'donald': 6,
#  'nonethless': 2,
#  'comfirming': 1,
#  'ing': 8,
#  'accurateupdated': 1,
#  'motorcycle': 20,
#  'van': 22,
#  'battery': 13,
#  'hasxxxxxxxxxxxx': 1,
#  'manipulation': 22,
#  'homei': 3,
#  'trauma': 5,
#  'expression': 1,
#  'munerous': 1,
#  'nto': 1,
#  'xxxxthat': 9,
#  'exemplar': 4,
#  'nonverified': 11,
#  'achools': 1,
#  'par': 20,
#  'obligatory': 7,
#  'mak': 3,
#  'fixin': 1,
#  'mulit': 1,
#  'utmost': 9,
#  'recored': 6,
#  'licesnese': 1,
#  'repotring': 1,
#  'belowlisted': 1,
#  'recusals': 2,
#  'closedopen': 1,
#  'heap': 3,
#  'che': 1,
#  'institutionalize': 1,
#  'againcurrently': 1,
#  'represenitive': 1,
#  'bearous': 1,
#  'misfile': 1,
#  'xxxxxxxxsource': 2,
#  'reportingnotices': 1,
#  'managerclerks': 2,
#  'disparaging': 2,
#  'wount': 1,
#  'unableunwilling': 4,
#  'gether': 1,
#  'ccasions': 2,
#  'wink': 2,
#  'commercialresidential': 1,
#  'gasket': 1,
#  'inqires': 2,
#  'oints': 1,
#  'threecredit': 2,
#  'currenly': 1,
#  'stockyard': 1,
#  'hurtle': 1,
#  'resurrect': 1,
#  'mylife': 1,
#  'documentscancelled': 1,
#  'passedtransferred': 1,
#  'nsumer': 1,
#  'xxxxlien': 1,
#  'falsei': 1,
#  'liers': 1,
#  'certailly': 1,
#  'montering': 2,
#  'finallyone': 1,
#  'xxxxtwice': 2,
#  'informationcredit': 1,
#  'valuepay': 1,
#  'ecti': 2,
#  'fileso': 1,
#  'reinitiated': 2,
#  'pu': 2,
#  'policyregslaw': 1,
#  'bareau': 1,
#  'meany': 1,
#  'brad': 1,
#  'debtscreditors': 2,
#  'toall': 1,
#  'continuedly': 1,
#  'fastforward': 1,
#  'telecon': 1,
#  'equifaxcomfcra': 1,
#  'organiaztion': 1,
#  'gestapo': 1,
#  'sdg': 1,
#  'erasure': 1,
#  'wholepart': 1,
#  'rnisher': 1,
#  'humanize': 1,
#  'incorrectfraud': 2,
#  'documentation': 5166,
#  'day': 15642,
#  'subject': 810,
#  'session': 35,
#  'among': 173,
#  'intend': 441,
#  'joint': 243,
#  'xxxxxxxxbecause': 3,
#  'sense': 343,
#  'hence': 103,
#  'inxxxxxxxx': 66,
#  'render': 130,
#  'unhelpful': 66,
#  'basically': 297,
#  'insubordination': 1,
#  'owedcharged': 4,
#  'fragment': 91,
#  'thread': 6,
#  'servicers': 32,
#  'identifaction': 1,
#  'cc': 247,
#  'sine': 5,
#  'steer': 11,
#  'graduate': 99,
#  'deliquient': 3,
#  'sketchy': 6,
#  'happenedto': 1,
#  'frankly': 45,
#  'adjuster': 9,
#  'badhands': 1,
#  'unto': 8,
#  'intelligent': 14,
#  'uncollectable': 3,
#  'dilemma': 13,
#  'quest': 16,
#  'insistent': 4,
#  'infraction': 22,
#  'frauddispute': 2,
#  'hypervigilant': 1,
#  'utilitiesfuel': 3,
#  'toreport': 1,
#  'backas': 1,
#  'inaccurateon': 1,
#  'eqiuifax': 3,
#  'pause': 6,
#  'cableinternet': 2,
#  'inent': 1,
#  'incomewelfare': 1,
#  'limitxxxxall': 1,
#  'fileequifax': 2,
#  'trhemselves': 1,
#  'underperformance': 1,
#  'liste': 1,
#  'notnever': 2,
#  'indidcated': 1,
#  'immunity': 2,
#  'departmentthis': 1,
#  'dishon': 1,
#  'eeuifax': 1,
#  'delinquencyxxxxxxxx': 1,
#  'togetter': 1,
#  'reconciliates': 1,
#  'verifiyed': 1,
#  'wwwconsumerfinancegovxxxx': 2,
#  'rootcause': 1,
#  'underling': 1,
#  'isplaying': 1,
#  'accountscollectioninquiries': 1,
#  'grammleach': 1,
#  'ishould': 1,
#  'procks': 1,
#  'sevens': 2,
#  'accountout': 1,
#  'promess': 1,
#  'bankruptciestax': 1,
#  'clandestine': 3,
#  'piss': 1,
#  'sistuations': 1,
#  'upconsequently': 1,
#  'timeusually': 1,
#  'libeled': 2,
#  'wetinked': 2,
#  'witb': 1,
#  'sssist': 1,
#  'promisorry': 1,
#  'originalinitial': 1,
#  'accs': 1,
#  'infoamtion': 1,
#  'practicei': 1,
#  'fcrai': 8,
#  'unverifiedinformation': 1,
#  'torelease': 1,
#  'lineitem': 1,
#  'xxxxremoveold': 1,
#  'prommissary': 1,
#  'litagation': 1,
#  'wk': 2,
#  'resolutionaccount': 1,
#  'backsaying': 1,
#  'chargerate': 1,
#  'helpingi': 1,
#  'thereafterwe': 1,
#  'repossson': 1,
#  'hant': 1,
#  'rly': 1,
#  'morgatge': 1,
#  'unessary': 1,
#  'happenhe': 1,
#  'linits': 1,
#  'addittion': 1,
#  'deflag': 1,
#  'surreal': 1,
#  'wirefraud': 1,
#  'agreedupon': 1,
#  'autodeposits': 1,
#  'credfit': 1,
#  'liftingplacing': 1,
#  'fiinance': 1,
#  'notpaid': 1,
#  'camouflage': 1,
#  'carpeting': 2,
#  'ipaidoffmyxxxxxxxxxxxxcreditcardthatpostedtomyaccountonxxxxicalledxxxxtoinquireaboutthecreditreportingupdateandtheysaidtheyonlyreportonthelastdayofthemonth': 1,
#  'fradulemt': 1,
#  'rateaccount': 1,
#  'pinellas': 1,
#  'balanceattached': 1,
#  'xxxxequifaxinquiries': 1,
#  'myfrustrationisasfollowswhyaretheynotsendingmemydisputeresultsviamail': 1,
#  'bearable': 1,
#  'investagation': 2,
#  'even': 7977,
#  'happen': 2142,
#  'ourthouse': 1,
#  'reinsert': 1153,
#  'cr': 117,
#  'stipulate': 49,
#  'crazy': 100,
#  'lein': 36,
#  'disabilitys': 1,
#  'supervision': 9,
#  'thou': 48,
#  'accountability': 85,
#  'disperse': 7,
#  'recordit': 1,
#  'circumvent': 22,
#  'pride': 16,
#  'sociali': 2,
#  'simular': 2,
#  'l': 172,
#  'bc': 124,
#  'cresit': 3,
#  'indigent': 6,
#  'instagram': 1,
#  'production': 11,
#  'wasam': 2,
#  'legwork': 5,
#  'uploads': 7,
#  'caner': 1,
#  'unclear': 40,
#  'reportcra': 1,
#  'dosent': 7,
#  'globalorganization': 1,
#  'accountsinquiries': 7,
#  'accuraciesplease': 1,
#  'ministry': 1,
#  'probation': 9,
#  'wednesdayxxxx': 1,
#  'investagated': 5,
#  'filied': 3,
#  'infirmation': 1,
#  'overdrfts': 1,
#  'assbume': 1,
#  'uncorrected': 3,
#  'creditmonitoring': 1,
#  'diversion': 2,
#  'mediation': 8,
#  'filesplease': 1,
#  'randomize': 5,
#  'introduction': 1,
#  'beau': 8,
#  'bmitted': 2,
#  'tradeslines': 1,
#  'debr': 1,
#  'fork': 1,
#  'para': 4,
#  'deletednullnon': 2,
#  'briefly': 10,
#  'delinquencyxxxx': 2,
#  'refinancedi': 1,
#  'trireport': 1,
#  'dfd': 1,
#  'centrol': 1,
#  'huseband': 1,
#  'marketplace': 3,
#  'realased': 1,
#  'allllll': 1,
#  'hie': 1,
#  'inaacruate': 1,
#  'jurisdictionthis': 1,
#  'oflaw': 1,
#  'statewide': 3,
#  'xxxxreport': 3,
#  'gentlebreezecom': 1,
#  'iens': 1,
#  'regaring': 3,
#  'fromxxxxxxxxxxxxxxxxxxxx': 1,
#  'numbername': 4,
#  'ifa': 1,
#  'delinquentcollection': 1,
#  'weekwhen': 1,
#  'extern': 2,
#  'attourney': 2,
#  'stsue': 1,
#  'listingsthe': 1,
#  'sstsynovus': 1,
#  'thecredit': 2,
#  'analogy': 2,
#  'truncation': 7,
#  'sgined': 1,
#  'sentxxxxxxxx': 1,
#  'inordinately': 2,
#  'accountsiam': 1,
#  'positivepayment': 1,
#  'megacompanies': 1,
#  'resolvedequifax': 1,
#  'accountsyou': 1,
#  'datecharge': 1,
#  'dipsuting': 1,
#  'forberance': 1,
#  'xxxxinquiryxxxx': 2,
#  'beause': 1,
#  'alreadyeven': 1,
#  'apb': 1,
#  'notificed': 2,
#  'complaintsxxxxof': 1,
#  'stationthey': 1,
#  'stringest': 1,
#  'explanationi': 1,
#  'tao': 2,
#  'palll': 1,
#  'banktypeminimum': 1,
#  'genie': 1,
#  'confm': 1,
#  'affaviadt': 1,
#  'frezz': 1,
#  'minethis': 1,
#  'incorrectnegative': 1,
#  'doortodoor': 1,
#  'realscore': 1,
#  'foryour': 1,
#  'jeapordizing': 1,
#  'investigational': 2,
#  'provocative': 1,
#  'depositnever': 1,
#  'saturdayxxxxxxxx': 1,
#  'perepetual': 1,
#  'avert': 1,
#  'prob': 2,
#  'companycollections': 1,
#  'deportment': 2,
#  'dem': 1,
#  'livedresidedgot': 1,
#  'whether': 1087,
#  'circle': 199,
#  'solvency': 65,
#  'ahead': 199,
#  'nonpayment': 30,
#  'imply': 81,
#  'bewildered': 5,
#  'convenience': 62,
#  'disclosure': 403,
#  'repair': 484,
#  'distrain': 1,
#  'space': 31,
#  'alabama': 115,
#  'numberthe': 2,
#  'cripple': 16,
#  'phyically': 1,
#  'lenderretailer': 1,
#  'throughout': 128,
#  'exclusive': 6,
#  'informationdispute': 1,
#  'annex': 9,
#  'iphone': 5,
#  'inexperienced': 6,
#  'anythingloans': 1,
#  'requre': 2,
#  'fir': 10,
#  'iquiry': 2,
#  'xxxxnquiry': 6,
#  'flexible': 10,
#  'grantortimes': 1,
#  'pr': 20,
#  'isaac': 2,
#  'accross': 2,
#  'hem': 4,
#  'inted': 1,
#  'mountain': 8,
#  ...}

# %%
companies = ['EQUIFAX, INC.',
 'Experian Information Solutions Inc.',
 'TRANSUNION INTERMEDIATE HOLDINGS, INC.',
 'BANK OF AMERICA, NATIONAL ASSOCIATION',
 'WELLS FARGO & COMPANY',
 'JPMORGAN CHASE & CO.',
 'CITIBANK, N.A.',
 'CAPITAL ONE FINANCIAL CORPORATION',
 'Navient Solutions, LLC.',
 'Ocwen Financial Corporation',
 'SYNCHRONY FINANCIAL',
 'NATIONSTAR MORTGAGE',
 'U.S. BANCORP',
 'AMERICAN EXPRESS COMPANY',
 'Ditech Financial LLC',
 'PNC Bank N.A.',
 'ENCORE CAPITAL GROUP INC.',
 'PORTFOLIO RECOVERY ASSOCIATES INC',
 'DISCOVER BANK',
 'TD BANK US HOLDING COMPANY']

# %%
from pyspark.sql.functions import explode, col

# initialize {company: {word counts}} dictionary
company_complaint_word_counts_dict = {company: {} for company in companies}

for company in companies:
    print(company)
    # get complaint narratives
    company_df = df.filter((df['company'] == company) 
                    & (df['consumer_complaint_narrative'].isNull() == False))
    data = company_df.select('consumer_complaint_narrative')
    
    # process narratives into counts dictionary
    clean_data = pipeline.fit(data).transform(data)
    clean_data_exploded = clean_data.withColumn("exploded_text", explode(col("finished_clean_lemma")))
    counts = clean_data_exploded.groupby('exploded_text').count().toPandas()
    counts_dict = {counts.loc[i, 'exploded_text']: counts.loc[i, 'count'] for i in range(counts.shape[0])}
    
    # add counts to dictionary
    company_complaint_word_counts_dict[company] = counts_dict
# Out:
# EQUIFAX, INC.
# Experian Information Solutions Inc.
# TRANSUNION INTERMEDIATE HOLDINGS, INC.
# BANK OF AMERICA, NATIONAL ASSOCIATION
# WELLS FARGO & COMPANY
# JPMORGAN CHASE & CO.
# CITIBANK, N.A.
# CAPITAL ONE FINANCIAL CORPORATION
# Navient Solutions, LLC.
# Ocwen Financial Corporation
# SYNCHRONY FINANCIAL
# NATIONSTAR MORTGAGE
# U.S. BANCORP
# AMERICAN EXPRESS COMPANY
# Ditech Financial LLC
# PNC Bank N.A.
# ENCORE CAPITAL GROUP INC.
# PORTFOLIO RECOVERY ASSOCIATES INC
# DISCOVER BANK
# TD BANK US HOLDING COMPANY

# %% [markdown]
# ## Tf-idf

# %%
def term_frequency(BoW_dict):
    tot_words = sum(BoW_dict.values())
    freq_dict = {word: BoW_dict[word]/tot_words for word in BoW_dict.keys()}
    return freq_dict

# %%
from math import log

def inverse_document_frequency(list_of_dicts):
    tot_docs = len(list_of_dicts)
    words = set([w for w_dict in list_of_dicts for w in w_dict.keys()])
    idf_dict = {word: log(float(tot_docs)/(1.0+ sum([1 for w_dict in list_of_dicts if word in w_dict.keys()]))) for word in words}
    return idf_dict

# %%
def tf_idf(list_of_dicts):
    words = set([w for w_dict in list_of_dicts for w in w_dict.keys()])
    tf_idf_dicts = []
    idfs = inverse_document_frequency(list_of_dicts)
    for w_dict in list_of_dicts:
        w_dict.update({word: 0 for word in words if word not in w_dict.keys()})
        tf = term_frequency(w_dict)
        tf_idf_dicts.append({word: tf[word]*idfs[word] for word in words})
    return tf_idf_dicts

# %%
list_of_word_dicts = [company_complaint_word_counts_dict[company] for company in companies]
tf_idf_by_company_list = tf_idf(list_of_word_dicts)
tf_idf_by_company_dict = {c: tf_dict for c, tf_dict in zip(companies, tf_idf_by_company_list)}

# %% [markdown]
# ## what's unique about each of our top companies (in terms of most compaints)?

# %%
import heapq

# %%
from nltk.corpus import words

eng_words = words.words()

for company in companies[0:10]:
    print ("\n", company)
    tf_idf_dict = tf_idf_by_company_dict[company]
    t100 = heapq.nlargest(100, tf_idf_dict, key=tf_idf_dict.get)
    t100 = {word: tf_idf_dict[word] for word in t100}
    t100 = [(k, v) for k, v in zip(t100.keys(), t100.values())]
    t100 = sorted(t100, key=lambda x: x[1], reverse=True)
    
    counter = 0
    for word, tfidf in t100:
        if counter < 10:
            if word in eng_words:
                counter += 1
                print (word, tfidf)
# Out:
#  EQUIFAX, INC.
# reseller 0.0002688113448994784
# tobe 0.00011921055656363865
# accuser 6.927943339562246e-05
# reinsertion 6.873224017786062e-05
# certifiably 6.287826619016647e-05
# certifiable 5.514274765382813e-05
# runner 4.9931123168016185e-05
# compliantly 4.7578859720163194e-05
# counteraction 4.0577767192584324e-05
# rejectable 3.6200064296811736e-05
#
#  Experian Information Solutions Inc.
# reseller 0.00027501965154673653
# tobe 0.00014687622941775372
# accuser 8.571715639653474e-05
# certifiably 7.710990986287158e-05
# certifiable 6.866771862714405e-05
# runner 6.281202094071141e-05
# reinsertion 5.664692062940039e-05
# compliantly 5.587557352215855e-05
# counteraction 4.989434077751539e-05
# rejectable 4.4865729243365284e-05
#
#  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# reseller 0.0003042826362853188
# tobe 0.00018786806000262364
# tu 0.0001447630541930031
# accuser 0.0001098803905320385
# certifiably 9.867512105377535e-05
# certifiable 8.755074575739848e-05
# compliantly 7.476791926979552e-05
# reinsertion 7.393924034451927e-05
# counteraction 6.71101733310887e-05
# automotive 6.59765529228018e-05
#
#  BANK OF AMERICA, NATIONAL ASSOCIATION
# boa 0.002601791649485743
# lynch 0.00021317211441412916
# bac 8.268148058932168e-05
# merchant 4.679212901191259e-05
# foreclose 4.5737780238272726e-05
# teller 4.080119277432391e-05
# platinum 3.0403277615214078e-05
# mellon 2.973787348481885e-05
# firearm 2.8966243483422735e-05
# mesne 2.6773531766979178e-05
#
#  WELLS FARGO & COMPANY
# preservation 0.00011058691165804388
# foreclose 5.753781062766643e-05
# appraisal 3.9504738341510795e-05
# preservationist 3.163435178085603e-05
# faro 3.119630797032966e-05
# teller 3.0855199973996694e-05
# dealer 2.8840062699925677e-05
# wels 2.8796591972611992e-05
# harp 2.627888546665399e-05
# yen 2.094920839524432e-05
#
#  JPMORGAN CHASE & CO.
# morgan 0.0018633127860989127
# sapphire 0.00042155429663852476
# southwest 0.00010974924949395894
# merchant 6.305054087767063e-05
# airway 4.9920903549298976e-05
# explorer 3.315799740490192e-05
# teller 3.110680856345583e-05
# mileage 2.9911618110749452e-05
# foreclose 2.862552616831636e-05
# chip 2.6531947912280743e-05
#
#  CITIBANK, N.A.
# depot 0.00030378309613007765
# promotional 9.267216727888594e-05
# goodyear 8.178787351660182e-05
# prestige 6.454169576756428e-05
# merchant 6.021662641408726e-05
# cit 5.619833352167643e-05
# dividend 5.3841648114814206e-05
# firearm 4.578598930519518e-05
# sear 3.997459383517256e-05
# platinum 3.951041951838869e-05
#
#  CAPITAL ONE FINANCIAL CORPORATION
# kohl 0.001678411867304545
# quicksilver 0.00024730629638458683
# savor 8.383264284223283e-05
# orchard 5.870988013205198e-05
# merchant 5.849909422914206e-05
# venture 4.975123629540618e-05
# rebill 4.045101320669507e-05
# platinum 3.6035707906554444e-05
# spark 2.9218141545854956e-05
# saver 2.6755386558840852e-05
#
#  Navient Solutions, LLC.
# pioneer 0.0003673137645965303
# mae 0.0003399697271674276
# unsubsidized 0.00026885770523046995
# diploma 5.7210786923799285e-05
# recertify 5.38658296551885e-05
# sally 5.328508048956544e-05
# salle 5.328508048956544e-05
# graduation 5.164994361446035e-05
# subsidize 4.538174657387051e-05
# reconsolidate 4.34521184309761e-05
#
#  Ocwen Financial Corporation
# homeward 0.0004597371937048256
# foreclose 0.00015073465073065314
# indy 0.00011407013076886652
# suspense 6.934210110075154e-05
# hooligan 6.222007132847264e-05
# sam 6.113523603137288e-05
# affiant 4.29440511897045e-05
# duplex 3.641965405987751e-05
# underwater 3.627725314946916e-05
# appraisal 3.318793066953237e-05

# %%
for company in companies:
    tf_idf_dict = tf_idf_by_company_dict[company]
    n_words = len([v for v in tf_idf_dict.values() if v > 0])
    print (f"{company}'s # of words: {n_words}")
# Out:
# EQUIFAX, INC.'s # of words: 24241
# Experian Information Solutions Inc.'s # of words: 22881
# TRANSUNION INTERMEDIATE HOLDINGS, INC.'s # of words: 21200
# BANK OF AMERICA, NATIONAL ASSOCIATION's # of words: 19820
# WELLS FARGO & COMPANY's # of words: 21038
# JPMORGAN CHASE & CO.'s # of words: 19433
# CITIBANK, N.A.'s # of words: 17386
# CAPITAL ONE FINANCIAL CORPORATION's # of words: 13188
# Navient Solutions, LLC.'s # of words: 13078
# Ocwen Financial Corporation's # of words: 10713
# SYNCHRONY FINANCIAL's # of words: 9969
# NATIONSTAR MORTGAGE's # of words: 9990
# U.S. BANCORP's # of words: 8568
# AMERICAN EXPRESS COMPANY's # of words: 8114
# Ditech Financial LLC's # of words: 6520
# PNC Bank N.A.'s # of words: 5405
# ENCORE CAPITAL GROUP INC.'s # of words: 3876
# PORTFOLIO RECOVERY ASSOCIATES INC's # of words: 3699
# DISCOVER BANK's # of words: 6392
# TD BANK US HOLDING COMPANY's # of words: 5094
